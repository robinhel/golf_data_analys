# %% [markdown]
# # Golf data analys
# ## PGA Tour 2010 - 2018

# %% [markdown]
# ## Bakgrund och syfte
#
# Datasetet kommer från Kaggle och innehåller statistik från PGA Tour säsongerna 2010–2018. Varje rad representerar en spelares samlade statistik för varje år.
#
# Jag är intresserad av golf och använde det här datasetet för att försöka svara på en fråga som faktiskt berör mitt eget spel vad är det egentligen som avgör om man presterar bra? Slår man för lite med drivern, lägger för mycket tid på putting-greenen, eller är det järnspelet som är nyckeln?
#
# Populationen är professionella spelare på PGA Tour världens högsta nivå. Det begränsar hur direkt jag kan översätta insikterna till mitt eget spel, men mönstren kan ändå peka i en riktning.
#
# **Kolumner av intresse:**
# - `Avg Distance` – genomsnittlig driving distance i yards
# - `Fairway Percentage` – andel drives som landar i fairway
# - `Average Score` – genomsnittlig score per runda
# - `Wins` – antal vinster under säsongen
# - `SG:OTT` – Strokes Gained Off The Tee (driving)
# - `SG:APR` – Strokes Gained Approach (järnspel)
# - `SG:ARG` – Strokes Gained Around The Green (nearspel)
# - `Average SG Putts` – Strokes Gained Putting

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('pgaTourData.csv')


df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2312 entries, 0 to 2311
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Player Name         2312 non-null   str
#  1   Rounds              1678 non-null   float64
#  2   Fairway Percentage  1678 non-null   float64
#  3   Year                2312 non-null   int64
#  4   Avg Distance        1678 non-null   float64
#  5   gir                 1678 non-null   float64
#  6   Average Putts       1678 non-null   float64
#  7   Average Scrambling  1678 non-null   float64
#  8   Average Score       1678 non-null   float64
#  9   Points              2296 non-null   str
#  10  Wins                293 non-null    float64
#  11  Top 10              1458 non-null   float64
#  12  Average SG Putts    1678 non-null   float64
#  13  Average SG Total    1678 non-null   float64
#  14  SG:OTT              1678 non-null   float64
# ...

# %% [markdown]
# ## Datatvätt
#
# **Rounds (634 saknade rader):** Spelare utan runddata saknar all spelstatistik, ta bort.
#
# **Money och Points:** Lagrade som text 2,680,487. Rensar bort och kommatecken och konverterar till tal. Används inte i visualiseringarna så kvarstående NaN spelar ingen roll.
#
# **Wins (2 019 NaN) och Top 10 (854 NaN):** Fylls i med 0. Rimligt eftersom de flesta spelare inte vinner eller toppar under en säsong men det är ett antagande.
#
# Inga dubletter. Inga orimliga värden.

# %% [markdown]
# ## Datatvätt

# %%
# 1. Ta bort rader som saknar all spelstatistik (ingen Rounds = ingen speldata)
df = df.dropna(subset=["Rounds"])

# 2. Hjälpfunktion: gör om "1,234,567" / "$1,234,567" till tal (funkar även om kolumnen redan är numerisk)
def _to_number(series: pd.Series) -> pd.Series:
    cleaned = series.astype(str).str.replace(r"[^0-9.\-]", "", regex=True)
    return pd.to_numeric(cleaned, errors="coerce")

# 3. Konvertera Money och Points till tal
df["Money"] = _to_number(df["Money"])
df["Points"] = _to_number(df["Points"])

# 4. Fyll i 0 för Wins och Top 10
# Antagande: NaN = 0 vinster/placeringar, inte saknad data.
df["Wins"] = df["Wins"].fillna(0)
df["Top 10"] = df["Top 10"].fillna(0)

df.head()

df.info()

df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1678 entries, 0 to 1677
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Player Name         1678 non-null   str
#  1   Rounds              1678 non-null   float64
#  2   Fairway Percentage  1678 non-null   float64
#  3   Year                1678 non-null   int64
#  4   Avg Distance        1678 non-null   float64
#  5   gir                 1678 non-null   float64
#  6   Average Putts       1678 non-null   float64
#  7   Average Scrambling  1678 non-null   float64
#  8   Average Score       1678 non-null   float64
#  9   Points              1674 non-null   float64
#  10  Wins                1678 non-null   float64
#  11  Top 10              1678 non-null   float64
#  12  Average SG Putts    1678 non-null   float64
#  13  Average SG Total    1678 non-null   float64
#  14  SG:OTT              1678 non-null   float64
# ...

# %% [markdown]
# # vilka spelare har bäst scoring average?

# %%
# Ta fram topp-10 spelare med lägst (bäst) genomsnittlig score
top_scoring = (
    df[["Player Name", "Average Score"]]
      .dropna()
      .groupby("Player Name", as_index=False)["Average Score"]
      .mean()
      .rename(columns={"Average Score": "avg_score"})
      .sort_values("avg_score", ascending=True)
      .head(10)
 )

fig, ax = plt.subplots(figsize=(9, 7))

ax.barh(top_scoring["Player Name"], top_scoring["avg_score"], color="#2e86c1")
ax.invert_yaxis()
ax.set_xlim(69, 70)

ax.set_title("Dessa 10 spelare har bäst scoring average på PGA Tour")
ax.set_xlabel("Genomsnittlig score (slag)")
ax.set_ylabel("Spelare")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### diffen på spelare(goat) och top 10 skiljer mindre änn average 1 slag!

# %% [markdown]
# # hur förändras driving distance på år?

# %%
distance_per_year = (
    df.groupby("Year")["Avg Distance"]
      .mean()
      .reset_index()
)

fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(distance_per_year["Year"], distance_per_year["Avg Distance"], marker="o", color="#2e86c1")
ax.set_title("Spelarna slår längre för varje år")
ax.set_xlabel("År")
ax.set_ylabel("Genomsnittlig driving distance (yards)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Driving distance har ökat särskilt mycket mellan 2013–2018,
# ### vilket troligtvis beror på förbättrad utrustning och träningsmetoder.
# ### 2013 kanske något regeländring eller något hände
# ###

# %% [markdown]
# # Vad är det igentligen som vinner matcherna? långa drives eller få putts?

# %%
# Korrelation mellan vinster och olika delar av spelet
cols = ["SG:OTT", "SG:APR", "SG:ARG", "Average SG Putts"]
corr = df[cols].corrwith(df["Wins"])

fig, ax = plt.subplots(figsize=(8, 5))
ax.hlines(range(len(corr)), 0, corr.values, color="#2e86c1", alpha=0.6)
ax.plot(corr.values, range(len(corr)), "o", color="#2e86c1")

ax.set_yticks(range(len(corr)))
ax.set_yticklabels(["Driving (OTT)", "Järnspel (APR)", "Runt green (ARG)", "Putting"])
ax.set_title("Vad vinner matcher – driving eller putting?")
ax.set_xlabel("Korrelation med vinster")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 fig, ax = plt.subplots(figsize=(8, 5))
# ----> 2 ax.hlines(range(len(corr)), 0, corr.values)
#       3 ax.plot(corr.values, range(len(corr)), "o")
#       4
#       5 ax.set_yticks(range(len(corr)))
#
# NameError: name 'corr' is not defined

# %% [markdown]
# ### Järnspel och driving spelar större roll än putting, trots vad alla pensionärer säger när jag tar allt jag har med drivern!
#
# #### Analysen visar att järnspel (APR) och driving (OTT) korrelerar starkare med vinster än putting och närspel.
# #### På PGA Tour-nivå verkar det alltså vara järnspelet som avgör, inte puttern.

# %% [markdown]
# # kan korta slag vara fördelsaktiga?

# %%
scatter_df = df[["Player Name", "Avg Distance", "Average Score"]].dropna()

fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(scatter_df["Avg Distance"], scatter_df["Average Score"], alpha=0.3, color="#2e86c1")

tiger = scatter_df[scatter_df["Player Name"] == "Tiger Woods"].iloc[0]
ax.annotate(
    "Tiger Woods",
    xy=(tiger["Avg Distance"], tiger["Average Score"]),
    xytext=(tiger["Avg Distance"] + 5, tiger["Average Score"] - 0.5),
    arrowprops=dict(arrowstyle="->", color="red"),
    color="red"
)

ax.set_title("Längre drive leder inte alltid till bättre score")
ax.set_xlabel("Driving distance (yards)")
ax.set_ylabel("Genomsnittlig score (slag)")
# Out:
# Text(0, 0.5, 'Genomsnittlig score (slag)')

# %% [markdown]
# # kortare slag = mer fairways?

# %%
fairway_df = df[["Player Name", "Avg Distance", "Fairway Percentage"]].dropna()

fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(fairway_df["Avg Distance"], fairway_df["Fairway Percentage"], alpha=0.3, color="#2e86c1")

tiger = fairway_df[fairway_df["Player Name"] == "Tiger Woods"].iloc[0]
ax.annotate(
    "Tiger Woods",
    xy=(tiger["Avg Distance"], tiger["Fairway Percentage"]),
    xytext=(tiger["Avg Distance"] + 5, tiger["Fairway Percentage"] + 2),
    arrowprops=dict(arrowstyle="->", color="red"),
    color="red"
)

ax.set_title("Längre drive = sämre fairway träff")
ax.set_xlabel("Driving distance (yards)")
ax.set_ylabel("Fairway träff (%)")
# Out:
# Text(0, 0.5, 'Fairway träff (%)')

# %% [markdown]
# ## Avslutning
#
# Järnspel och driving korrelerar mer med vinster än putting "putt for dough" verkar inte stämma på den här nivån. Längre drives ger sämre fairway träff, och toppspelarna skiljs åt med bråkdelar av ett slag.
#
# På tour nivå är alla redan bra på putting, så variationen syns i driving och järnspel istället. För en amatör som mig ser detta väldigt annorlunda ut.
#
# Ändå pekar det i en riktning, mer tid på järnspelet, mindre på putting greenen.
